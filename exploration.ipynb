# %%
import pandas as pd
# %matplotlib inline

df = pd.read_csv('./train.csv.gz')

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
df[:10]
# Out:
#            x0          x1          x2          x3          x4          x5  x6  \
# 0  b4d8a653ea  16a14a2d17  06330986ed  ca63304de0  a62168d626  1746600cb0   1
# 1  467f9617a3  16a14a2d17  06330986ed  ca63304de0  b7584c2d52  1746600cb0   1
# 2  190436e528  16a14a2d17  06330986ed  ca63304de0  b7584c2d52  1746600cb0   1
# 3  43859085bc  16a14a2d17  06330986ed  ca63304de0  a62168d626  1746600cb0   1
# 4  a4c3095b75  16a14a2d17  06330986ed  ca63304de0  b7584c2d52  1746600cb0   1
# 5  aa2f3cd34a  16a14a2d17  06330986ed  ca63304de0  b7584c2d52  1746600cb0   1
# 6  bd17e19b3a  16a14a2d17  06330986ed  ca63304de0  b7584c2d52  1746600cb0   1
# 7  bfff7d2d9e  16a14a2d17  06330986ed  ca63304de0  a62168d626  1746600cb0   1
# 8  715b3c485f  16a14a2d17  06330986ed  ca63304de0  a62168d626  1746600cb0   1
# 9  aa2f3cd34a  16a14a2d17  06330986ed  ca63304de0  b7584c2d52  1746600cb0   1
#
#    x7        x8          x9         x10         x11         x12      x13  \
# ...

# %%
df.y.value_counts()
# Out:
# 2    15774
# 3    14677
# 4    10012
# 5     5419
# 1     1964
# 6     1793
# 0      361
# Name: y, dtype: int64

# %%
pd.DataFrame([(col, df[col].nunique()) for col in df.columns if df[col].dtype.name == 'object'])
# Out:
#       0     1
# 0    x0    85
# 1    x1    15
# 2    x2     2
# 3    x3     2
# 4    x4     5
# 5    x5     6
# 6    x9     7
# 7   x10  1849
# 8   x11     4
# 9   x12     7
# 10  x14    39
# 11  x15     2
# 12  x16    10
# 13  x17    84
# 14  x18  3350
# 15  x19    13
# 16  x20    86
# 17  x21  4236
# 18  x22     8

# %%
import seaborn as sns

sns.set(style='ticks')

# %%
df.y.hist()

# %%
df.x10.value_counts()[:10]
# Out:
# 37eee1916c    1074
# abf7f8e744     900
# ff3ea89708     801
# 2b1a0a7c41     784
# 7bfe5c2f5a     593
# 350b7d04c7     513
# 1d42d0c490     489
# 269ba9924e     455
# d16502f4dc     400
# 47bdeb833e     356
# Name: x10, dtype: int64

# %%
df.x18.value_counts()[:10]
# Out:
# cac4fc8eaf    2272
# 9e166b965d    1353
# 8ff9e52879    1231
# 28e6a6b9f5    1080
# 969b7983fb    1045
# a3c4c5634c     790
# 8961c83e4a     644
# b17fdf125c     560
# 22395cacfc     547
# 356c022be1     521
# Name: x18, dtype: int64

# %%
df.x21.value_counts()[:10]
# Out:
# 64ebc0a062    1149
# e3c03ca55c     707
# 0fc56ea1f0     615
# c6b4ad548f     528
# b1407db9a8     489
# c9eae35966     433
# fadc90b449     347
# 82a0e4c048     347
# 99f6ada51c     338
# 14d0ac06f1     302
# Name: x21, dtype: int64
